# %% [markdown]
# <a href="https://colab.research.google.com/github/mccarthyajb/HL-NTAC/blob/main/TheBarplot_300.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('./mount')
print("Drive Mounted")

import numpy as np
import pandas as pd
# Barplot

names = []


flat_original_f1_macros =[]
flat_jsma_f1_macros = []
hier_original_f1_macros =[]
hier_jsma_f1_macros = []
fine_hier_original_f1_macros =[]
fine_hier_jsma_f1_macros = []

hier_original_layer1 = []
hier_original_layer2 = []

hier_jsma_layer1 = []
hier_jsma_layer2 = []

conditions = []

# names.append('Flat MLP')
# original_f1_macros.append()
# jsma_f1_macros.append()
# conditions.append('Ordinary')
# conditions.append('JSMA')

# ==========================================

names.append('K-Means')
flat_original_f1_macros.append(0.88)
flat_jsma_f1_macros.append(0.48)

# hier_original_f1_macros.append(0.778761)
# hier_jsma_f1_macros.append(0.575221)

hier_original_layer1.append(0.95)
hier_original_layer2.append(0.92)

hier_jsma_layer1.append(0.73)
hier_jsma_layer2.append(0.62)

# ==========================================

names.append('Ward')

flat_original_f1_macros.append(0.87)
flat_jsma_f1_macros.append(0.44)

hier_original_layer1.append(0.95)
hier_original_layer2.append(0.91)

hier_jsma_layer1.append(0.73)
hier_jsma_layer2.append(0.72)

# ==========================================



names.append('Average')

flat_original_f1_macros.append(0.88)
flat_jsma_f1_macros.append(0.46)


hier_original_layer1.append(0.99)
hier_original_layer2.append(0.91)

hier_jsma_layer1.append(0.87)
hier_jsma_layer2.append(0.71)

# ==========================================

names.append('Complete')

flat_original_f1_macros.append(0.83)
flat_jsma_f1_macros.append(0.57)


hier_original_layer1.append(0.96)
hier_original_layer2.append(0.92)

hier_jsma_layer1.append(0.85)
hier_jsma_layer2.append(0.68)


# ==========================================


names.append('Single')
flat_original_f1_macros.append(0.86)
flat_jsma_f1_macros.append(0.38)


hier_original_layer1.append(0.99)
hier_original_layer2.append(0.90)

hier_jsma_layer1.append(0.91)
hier_jsma_layer2.append(0.49)

# ==========================================

names.append('Researcher')

flat_original_f1_macros.append(0.82)
flat_jsma_f1_macros.append(0.46)

hier_original_layer1.append(0.93)
hier_original_layer2.append(0.89)

hier_jsma_layer1.append(0.71)
hier_jsma_layer2.append(0.60)

# ==========================================

names.append('Dataset')

flat_original_f1_macros.append(0.87)
flat_jsma_f1_macros.append(0.49)

hier_original_layer1.append(0.98)
hier_original_layer2.append(0.92)

hier_jsma_layer1.append(0.78)
hier_jsma_layer2.append(0.62)






for name in names:
  conditions.append('Flat MLP Ordinary')

for name in names:
  conditions.append('Flat MLP JSMA')


for name in names:
    conditions.append('Hierarchy Layer1 Ordinary')

for name in names:
    conditions.append('Hierarchy Layer2 Ordinary')

for name in names:
    conditions.append('Hierarchy Layer1 JSMA')

for name in names:
    conditions.append('Hierarchy Layer2 JSMA')


flat_orig_df = pd.DataFrame(np.column_stack([names, flat_original_f1_macros]), 
                               columns=['Clustering Type', 'F1-Score'])
flat_adversarial_df = pd.DataFrame(np.column_stack([names, flat_jsma_f1_macros]), 
                               columns=['Clustering Type', 'F1-Score'])

hier_orig_df = pd.DataFrame(np.column_stack([names, hier_original_layer1]), 
                               columns=['Clustering Type', 'F1-Score'])
hier_orig_df2 = pd.DataFrame(np.column_stack([names, hier_original_layer2]), 
                               columns=['Clustering Type', 'F1-Score'])

frames = [hier_orig_df,hier_orig_df2]

hier_orig_df = pd.concat(frames)


hier_adversarial_df = pd.DataFrame(np.column_stack([names, hier_jsma_layer1]), 
                               columns=['Clustering Type', 'F1-Score', ])

hier_adversarial_df2 = pd.DataFrame(np.column_stack([names, hier_jsma_layer2]), 
                               columns=['Clustering Type', 'F1-Score', ])

frames = [hier_adversarial_df,hier_adversarial_df2]

hier_adversarial_df = pd.concat(frames)



group_frames = [flat_orig_df,flat_adversarial_df, hier_orig_df,hier_adversarial_df]
group_df = pd.concat(group_frames)


group_df['Conditions'] = conditions
group_df[['F1-Score']] = group_df[['F1-Score']].apply(pd.to_numeric)
print(group_df)
group_df = group_df.round(decimals=2)
# group_df = group_df.sort_values('F1-Score')
# group_df = group_df.sort_values('Clustering Type')

import matplotlib.pyplot as plt
import seaborn as sns


import matplotlib.pyplot as plt
import seaborn as sns

#set seaborn plotting aesthetics
sns.set(style='white')
sns.set_context("paper")
sns.color_palette("dark:salmon_r", as_cmap=True)

#create grouped bar chart hue_order={'Ordinary','Adversarial'}
bar = sns.barplot(x='Clustering Type', y='F1-Score', ci=95, hue='Conditions', hue_order=['Flat MLP Ordinary','Flat MLP JSMA',
                                                                             'Hierarchy Layer1 Ordinary', 'Hierarchy Layer2 Ordinary', 
                                                                             'Hierarchy Layer1 JSMA', 'Hierarchy Layer2 JSMA'], data=group_df)
            # palette=['purple', 'steelblue'])
            # palette=['orange', 'red'])

# hue_order={'Flat MLP Ordinary','Flat MLP JSMA', 'Hierarchy MLP Ordinary','Hierarchy MLP JSMA'},


bar.grid(b=True, which='major', color='black', linewidth=0.075)
bar.grid(b=True, which='minor', color='black', linewidth=0.075)
# Define some hatches
hatches = [ '/',  '/', '/', '/', '/', '/', '/', '/', '/', '/', '/',
            '//', '//', '//', '//', '//', '//', '//', '//', '//', '//', '//',
            '///', '///', '///', '///', '///', '///', '///', '///', '///', '///', '///',
            '////', '////', '////', '////', '////', '////', '////', '////', '////', '////', '////',
            
           ] # , 'x', '\\', '*', 'o']

# Loop over the bars
for i,thisbar in enumerate(bar.patches):
    # Set a different hatch for each bar
    thisbar.set_hatch(hatches[i])


# #set seaborn plotting aesthetics
# sns.set(style='white')

# #create grouped bar chart
# sns.barplot(x='Clustering Type', y='F1-Score', hue='Conditions', hue_order={'Ordinary','JSMA'}, data=group_df,
#             palette=['purple', 'steelblue'])

#add overall title
plt.title('F1-Score Macro Avg by \nHierarchy Type (Ordinary Vs. JSMA)', fontsize=16)

#add axis titles
plt.xlabel('Clustering Type')
plt.ylabel('F1-Score Macro Avg')

#rotate x-axis labels
plt.xticks(rotation=0)
plt.ylim(0.0,1.00)
# Put the legend out of the figure
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.legend(bbox_to_anchor=(-0.1, -0.2), ncol=3, loc=2, borderaxespad=0.)
bar.axhline(0.47,color='orange')

bar.axhline(0.63,color='brown')
#save the plot
basedir='mount/My Drive/Colab Notebooks/Figures/'
savename='Thebigbarplot.png'
filename=basedir+savename
plt.savefig(filename,dpi=300,bbox_inches='tight')

orange = 0.47
brown = 0.63

difference = brown - orange 
print(difference)

percent = difference / orange * 100 
print(percent)


print(f'In particular we note an average improvement of {percent} \% in classification of presented adversarial samples: an increase of ${difference}$ from ${orange}$ to ${brown}$. This improvement can be seen in the difference between the orange and brown horizontal lines.')

blue = 0.86
red = 0.91

difference = red - blue
print(difference)
percent = (difference / blue) * 100

print(f'Moreover, we note an average improvement in robustness of classification in general of {percent} \% when only original unperturbed samples are presented: an increase of {difference} from {blue} to {red}')
# Out:
# Drive already mounted at ./mount; to attempt to forcibly remount, call drive.mount("./mount", force_remount=True).
# Drive Mounted
#   Clustering Type  F1-Score                 Conditions
# 0         K-Means      0.88          Flat MLP Ordinary
# 1            Ward      0.87          Flat MLP Ordinary
# 2         Average      0.88          Flat MLP Ordinary
# 3        Complete      0.83          Flat MLP Ordinary
# 4          Single      0.86          Flat MLP Ordinary
# 5      Researcher      0.82          Flat MLP Ordinary
# 6         Dataset      0.87          Flat MLP Ordinary
# 0         K-Means      0.48              Flat MLP JSMA
# 1            Ward      0.44              Flat MLP JSMA
# 2         Average      0.46              Flat MLP JSMA
# 3        Complete      0.57              Flat MLP JSMA
# 4          Single      0.38              Flat MLP JSMA
# 5      Researcher      0.46              Flat MLP JSMA
# 6         Dataset      0.49              Flat MLP JSMA
# 0         K-Means      0.95  Hierarchy Layer1 Ordinary
# 1            Ward      0.95  Hierarchy Layer1 Ordinary
# 2         Average      0.99  Hierarchy Layer1 Ordinary
# 3        Complete      0.96  Hierarchy Layer1 Ordinary
# 4          Single      0.99  Hierarchy Layer1 Ordinary
# 5      Researcher      0.93  Hierarchy Layer1 Ordinary
# 6         Dataset      0.98  Hierarchy Layer1 Ordinary
# 0         K-Means      0.92  Hierarchy Layer2 Ordinary
# 1            Ward      0.91  Hierarchy Layer2 Ordinary
# 2         Average      0.91  Hierarchy Layer2 Ordinary
# 3        Complete      0.92  Hierarchy Layer2 Ordinary
# 4          Single      0.90  Hierarchy Layer2 Ordinary
# 5      Researcher      0.89  Hierarchy Layer2 Ordinary
# 6         Dataset      0.92  Hierarchy Layer2 Ordinary
# 0         K-Means      0.73      Hierarchy Layer1 JSMA
# 1            Ward      0.73      Hierarchy Layer1 JSMA
# 2         Average      0.87      Hierarchy Layer1 JSMA
# 3        Complete      0.85      Hierarchy Layer1 JSMA
# 4          Single      0.91      Hierarchy Layer1 JSMA
# 5      Researcher      0.71      Hierarchy Layer1 JSMA
# 6         Dataset      0.78      Hierarchy Layer1 JSMA
# 0         K-Means      0.62      Hierarchy Layer2 JSMA
# 1            Ward      0.72      Hierarchy Layer2 JSMA
# 2         Average      0.71      Hierarchy Layer2 JSMA
# 3        Complete      0.68      Hierarchy Layer2 JSMA
# 4          Single      0.49      Hierarchy Layer2 JSMA
# 5      Researcher      0.60      Hierarchy Layer2 JSMA
# 6         Dataset      0.62      Hierarchy Layer2 JSMA
# 0.16000000000000003
# 34.042553191489375
# In particular we note an average improvement of 34.042553191489375 \% in classification of presented adversarial samples: an increase of $0.16000000000000003$ from $0.47$ to $0.63$. This improvement can be seen in the difference between the orange and brown horizontal lines.
# 0.050000000000000044
# Moreover, we note an average improvement in robustness of classification in general of 5.813953488372099 \% when only original unperturbed samples are presented: an increase of 0.050000000000000044 from 0.86 to 0.91
